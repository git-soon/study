# %%
# !pip install opencv-python
import cv2
# Out:
# Requirement already satisfied: opencv-python in c:\anaconda\conda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\anaconda\conda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread('cat.jpg')
gray_image = cv2.imread('cat.jpg',cv2.IMREAD_GRAYSCALE) 


#color image의 경우 , BGR format을 RGB로 변환
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
#흑백 이미지의 경우 cmap을 gray로 설정, 디폴트는 녹색 느낌의 color map 사용
plt.imshow(gray_image,cmap = 'gray')
