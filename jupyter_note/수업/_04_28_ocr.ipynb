# %%
import cv2
from pytesseract import pytesseract
import matplotlib.pyplot as plt
import os

# %%
print(os.getcwd())

path = '..\..\static\car_number_1.jpg'
#path = './데이터/cat.jpg'
#path = './data/cat.jpg'
#path = './cat.jpg'
#path = '../../static/cat.jpg'

print(os.path.exists(path))


image = cv2.imread(path)
plt.imshow(image)
# Out:
# c:\Users\charl\OneDrive\Desktop\기타\coding\coding_on_study\study\jupyter_note\수업
# True
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\charl\AppData\Local\Temp\ipykernel_16412\1253587756.py:3: SyntaxWarning: invalid escape sequence '\.'
#   path = '..\..\static\car_number_1.jpg'

# %%
img = cv2.imread("..\/car_number_1.png")

print(img.shape)

plt.imshow(img, cmap="gray")
plt.axis('off')
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 img = cv2.imread("../car_number_1.png")
# ----> 3 print(img.shape)
#       5 plt.imshow(img, cmap="gray")
#       6 plt.axis('off')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
cor
